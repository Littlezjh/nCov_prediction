# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from models import LSTNet
import importlib

from utils import *;
import Optim

#显示中文
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

data_path='D:/Codes/nCov/LSTNet-master/data/'

# %%
inputfile="D:/Codes/nCov/data/out_increase_province_2.20.csv"

# 显示所有列
pd.set_option('display.max_columns', None)
# 显示所有行
pd.set_option('display.max_rows', None)
# 设置value的显示长度为100，默认为50
pd.set_option('max_colwidth', 200)

#读取数据
dataf = pd.read_csv(inputfile, encoding='UTF-8')

# %%
#提取对应省份的数据
data_zhejiang=dataf.loc[dataf['省']=='浙江省'].iloc[:,1:4]
print(data_zhejiang)
#对数据进行处理，将数据中的负数消除
for index,data in data_zhejiang.iterrows():
    for name in data.iteritems():
        if name[1]<0:
            data_zhejiang.loc[index+1,name[0]]+=name[1]
            data_zhejiang.loc[index,name[0]]=0
data_zj=data_zhejiang.iloc[::-1]
data_zj.to_csv(data_path+'data_zhejiang_2.20.txt', header=0,index=False)
# Out:
#     新增死亡  新增治愈   新增确诊
# 0    1.0   9.0    1.0
# 1    0.0  69.0    2.0
# 2    0.0  28.0    1.0
# 3    0.0  51.0    4.0
# 4    0.0  28.0    5.0
# 5    0.0  25.0    7.0
# 6    0.0  43.0   10.0
# 7    0.0  39.0   14.0
# 8    0.0  51.0   14.0
# 9    0.0  28.0   25.0
# 10   0.0  41.0   17.0
# 11   0.0  26.0   27.0
# 12   0.0  52.0   42.0
# 13   0.0  29.0   52.0
# 14   0.0  16.0   59.0
# 15   0.0  16.0   66.0
# 16   0.0  19.0  105.0
# 17  -1.0  11.0   63.0
# 18   1.0  11.0   62.0
# 19   0.0   7.0   61.0
# 20   0.0  10.0  110.0
# 21   0.0   1.0  132.0
# 22   0.0   0.0  123.0
# 23   0.0   2.0   45.0
# 24   0.0   0.0   24.0
# 25   0.0   0.0   42.0
# 26   0.0   0.0   19.0
# 27   0.0   1.0   43.0

# %%
#提取对应省份的数据
data_hb=dataf.loc[dataf['省']=='湖北省'].iloc[:,1:4]
print(data_hb)
# data_hb.iloc[5,2]=(data_hb.iloc[4,2]+data_hb.iloc[6,2])/2
#对数据进行处理，将数据中的负数消除
for index,data in data_hb.iterrows():
    for name in data.iteritems():
        if name[1]<0:
            data_hb.loc[index+1,name[0]]+=name[1]
            data_hb.loc[index,name[0]]=0
data_hb=data_hb.iloc[::-1]
data_hb.to_csv(data_path+'data_hubei_reduced_2.20.txt', header=0,index=False)
# Out:
#      新增死亡    新增治愈     新增确诊
# 28  108.0  1017.0    349.0
# 29  132.0  1393.0   1693.0
# 30   93.0  1250.0   1807.0
# 31  100.0  1027.0   1933.0
# 32  139.0   845.0   1843.0
# 33   31.0   690.0   2420.0
# 34  116.0   672.0   3780.0
# 35  242.0   773.0  14840.0
# 36   94.0   376.0   1638.0
# 37  103.0   456.0   2097.0
# 38   91.0   374.0   2531.0
# 39   81.0   262.0   2147.0
# 40   81.0   351.0   2841.0
# 41   69.0   155.0   2447.0
# 42   70.0   175.0   2987.0
# 43   65.0   139.0   3156.0
# 44   64.0    98.0   2345.0
# 45   56.0    33.0   2103.0
# 46   45.0    99.0   1921.0
# 47   45.0    27.0   1347.0
# 48   42.0    51.0    903.0
# 49   37.0     3.0   1349.0
# 50   25.0    35.0    840.0
# 51   24.0     5.0   1291.0
# 52   24.0     5.0    365.0
# 53   13.0    10.0    328.0
# 54   15.0     1.0    181.0
# 55   24.0    31.0    549.0

# %%
print(data_zj)
data_zj.plot(title='浙江省新增情况图',use_index=False)
plt.savefig('figure/zhejiang.png',dpi=500)
plt.show()
# Out:
#     新增死亡  新增治愈   新增确诊
# 27   0.0   1.0   43.0
# 26   0.0   0.0   19.0
# 25   0.0   0.0   42.0
# 24   0.0   0.0   24.0
# 23   0.0   2.0   45.0
# 22   0.0   0.0  123.0
# 21   0.0   1.0  132.0
# 20   0.0  10.0  110.0
# 19   0.0   7.0   61.0
# 18   0.0  11.0   62.0
# 17   0.0  11.0   63.0
# 16   0.0  19.0  105.0
# 15   0.0  16.0   66.0
# 14   0.0  16.0   59.0
# 13   0.0  29.0   52.0
# 12   0.0  52.0   42.0
# 11   0.0  26.0   27.0
# 10   0.0  41.0   17.0
# 9    0.0  28.0   25.0
# 8    0.0  51.0   14.0
# 7    0.0  39.0   14.0
# 6    0.0  43.0   10.0
# 5    0.0  25.0    7.0
# 4    0.0  28.0    5.0
# 3    0.0  51.0    4.0
# 2    0.0  28.0    1.0
# 1    0.0  69.0    2.0
# 0    1.0   9.0    1.0

# %%
data_hb.plot(title='湖北省新增情况图',use_index=False)
plt.savefig('figure/hubei.png',dpi=500)
plt.show()

# %%
#读取模型
with open('save/hubei.pt', 'rb') as f:
    model = torch.load(f)
# data_zj=pd.read_table('data/data_hubei.txt',header=None,sep=',')
data_zj=pd.read_table('data/data_hubei_2.26.txt',header=None,sep=',')
data_zj=data_zj[::-1]
print(data_zj)
# Out:
#         0       1        2
# 33   52.0  1986.0    401.0
# 32   68.0  2223.0    499.0
# 31  149.0  1405.0    203.0
# 30   96.0  1653.0    630.0
# 29  106.0  1809.0    792.0
# 28  115.0  1360.0    631.0
# 27  108.0  1185.0    349.0
# 26  132.0  1393.0   1693.0
# 25   93.0  1250.0   1807.0
# 24  100.0  1027.0   1933.0
# 23  139.0   845.0   1843.0
# 22   31.0   690.0   2420.0
# 21  116.0   672.0   3780.0
# 20  242.0   773.0  14840.0
# 19   94.0   376.0   1638.0
# 18  103.0   456.0   2097.0
# 17   91.0   374.0   2531.0
# 16   81.0   262.0   2147.0
# 15   81.0   351.0   2841.0
# 14   69.0   155.0   2447.0
# 13   70.0   175.0   2987.0
# 12   65.0   139.0   3156.0
# 11   64.0    98.0   2345.0
# 10   56.0    33.0   2103.0
# 9    45.0    99.0   1921.0
# 8    45.0    27.0   1347.0
# 7    42.0    51.0    903.0
# 6    37.0     3.0   1349.0
# 5    25.0    35.0    840.0
# 4    24.0     5.0   1291.0
# 3    24.0     5.0    365.0
# 2    13.0    10.0    328.0
# 1    15.0     1.0    181.0
# 0    24.0    31.0    549.0

# %%
i=0
dt=data_zj.iloc[5:10,:]
dt=dt[::-1]
#预测的前5个值
first_5=dt
dt=dt.values
dt=np.expand_dims(dt,axis=0)
print(dt)
x=Variable(torch.FloatTensor(dt))
y=model(x).data.numpy()
Y=np.expand_dims(y,axis=0)
#预测的后5个值
later_5=pd.DataFrame(y)
# Out:
# [[[ 100. 1027. 1933.]
#   [  93. 1250. 1807.]
#   [ 132. 1393. 1693.]
#   [ 108. 1185.  349.]
#   [ 115. 1360.  631.]]]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-dd82e3215a34> in <module>
#       8 print(dt)
#       9 x=Variable(torch.FloatTensor(dt))
# ---> 10 y=model(x).data.numpy()
#      11 Y=np.expand_dims(y,axis=0)
#      12 #预测的后5个值
#
# D:\Software\Anaconda\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# D:\Codes\nCov\LSTNet-master\models\LSTNet.py in forward(self, x)
#      36
#      37         #CNN
# ---> 38         c = x.view(-1, 1, self.P, self.m);
#      39         c = F.relu(self.conv1(c));
#      40         c = self.dropout(c);
#
# RuntimeError: shape '[-1, 1, 7, 3]' is invalid for input of size 15

# %%
new_dt=dt[:,1:,:]
dt_1=np.concatenate((new_dt,Y),axis=1)
for i in range(4):
    x=Variable(torch.FloatTensor(dt_1))
    y=model(x).data.numpy()
    Y=np.expand_dims(y,axis=0)
    later_5=later_5.append(pd.DataFrame(y))
    dt_1=dt_1[:,1:,:]
    dt_1=np.concatenate((dt_1,Y),axis=1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-5849d8707cb6> in <module>
#       3 for i in range(4):
#       4     x=Variable(torch.FloatTensor(dt_1))
# ----> 5     y=model(x).data.numpy()
#       6     Y=np.expand_dims(y,axis=0)
#       7     later_5=later_5.append(pd.DataFrame(y))
#
# D:\Software\Anaconda\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# D:\Codes\nCov\LSTNet-master\models\LSTNet.py in forward(self, x)
#      36
#      37         #CNN
# ---> 38         c = x.view(-1, 1, self.P, self.m);
#      39         c = F.relu(self.conv1(c));
#      40         c = self.dropout(c);
#
# RuntimeError: shape '[-1, 1, 7, 3]' is invalid for input of size 15

# %%
predict_10=first_5.append(later_5).reset_index(drop=True)
print(predict_10)
# Out:
#             0            1            2
# 0  100.000000  1027.000000  1933.000000
# 1   93.000000  1250.000000  1807.000000
# 2  132.000000  1393.000000  1693.000000
# 3  108.000000  1185.000000   349.000000
# 4  115.000000  1360.000000   631.000000
# 5   60.643726   695.532410   307.579407
# 6   40.678005   464.690643   207.901993
# 7   25.731251   288.027649   128.990768
# 8   16.695528   181.681595    81.653107
# 9   10.987301   114.443863    51.721554

# %%
#读取真实值
data_true=data_zj.iloc[:10,:].reset_index(drop=True)
data_true=data_true[::-1]
print(data_true)
# Out:
#        0       1       2
# 9  100.0  1027.0  1933.0
# 8   93.0  1250.0  1807.0
# 7  132.0  1393.0  1693.0
# 6  108.0  1185.0   349.0
# 5  115.0  1360.0   631.0
# 4  106.0  1809.0   792.0
# 3   96.0  1653.0   630.0
# 2  149.0  1405.0   203.0
# 1   68.0  2223.0   499.0
# 0   52.0  1986.0   401.0

# %%
import matplotlib.dates as mdate

#显示新增治愈图像
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),data_true.iloc[:,1],label='实际值')
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),predict_10.iloc[:,1],label='预测值')
plt.legend()
ax = plt.gca() 
ax.xaxis.set_major_formatter(mdate.DateFormatter('%m/%d')) 
plt.title('湖北省新增治愈对比图')
plt.savefig('figure/湖北省新增治愈对比图_LSTnet.png',dpi=500)

# %%
ax = plt.gca() 
ax.xaxis.set_major_formatter(mdate.DateFormatter('%m/%d')) 
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),data_true.iloc[:,2],label='实际值')
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),predict_10.iloc[:,2],label='预测值')
plt.legend()
plt.title('湖北省新增确诊对比图')
plt.savefig('figure/湖北省新增确诊对比图_LSTnet.png',dpi=500)

# %%
ax = plt.gca() 
ax.xaxis.set_major_formatter(mdate.DateFormatter('%m/%d')) 
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),data_true.iloc[:,0],label='实际值')
plt.plot(pd.date_range('2020-2-17','2020-2-26',freq='1d'),predict_10.iloc[:,0],label='预测值')
plt.legend()
plt.title('湖北省新增死亡对比图')
plt.savefig('figure/湖北省新增死亡对比图_LSTnet.png',dpi=500)
